# %%
data = open("small.txt", 'r')

# %%
data.readline()
# Out:
# '   2.0000000e+00   8.2084817e-01   2.7969154e-01  -9.3380864e-01   5.3144612e-01  -2.8994726e-01   8.1788159e-02   7.1894153e-01  -2.5073776e-01  -2.2245984e+00   1.3935927e+00\n'

# %%
import pandas as pd

# %%
df = pd.read_fwf("small.txt",header=None)

# %%
df
# Out:
#       0         1         2         3         4         5         6   \
# 0    2.0  0.820848  0.279692 -0.933809  0.531446 -0.289947  0.081788
# 1    2.0 -0.237337  0.123457 -0.147219 -0.169008 -1.906988  0.412150
# 2    2.0 -1.004144 -0.363469 -2.368783  0.188795  0.649362 -0.663043
# 3    2.0 -0.303728 -0.025726 -1.275006 -0.609765  0.306372  0.196949
# 4    2.0 -0.750953 -1.433361  1.147996  1.286011  1.305121  0.664181
# ..   ...       ...       ...       ...       ...       ...       ...
# 495  1.0 -0.848163 -0.807881 -0.123273 -0.744263  0.467340 -1.309142
# 496  2.0  0.055388  0.021084  0.559810 -0.503055 -0.968667  1.684491
# 497  2.0 -0.753129 -1.264581 -1.127424 -0.554393 -0.609218 -0.047186
# 498  2.0 -0.231799 -0.276941 -2.064353 -2.093766 -0.616740 -0.390248
# 499  2.0 -0.011838 -0.465866  0.319968 -1.095462 -1.666040 -0.517896
#
#            7         8         9         10
# 0    0.718942 -0.250738 -2.224598  1.393593
# 1   -0.476520  0.049739 -0.578898  1.474495
# ...

# %%
df.at[0,0]
# Out:
# 2.0

# %%
df.iloc[0,1:]
# Out:
# 1     0.820848
# 2     0.279692
# 3    -0.933809
# 4     0.531446
# 5    -0.289947
# 6     0.081788
# 7     0.718942
# 8    -0.250738
# 9    -2.224598
# 10    1.393593
# Name: 0, dtype: float64

# %%
df.iloc[0,1:].size
# Out:
# 10

# %%
df.iloc[0:,[1,2,3]]
# Out:
#             1         2         3
# 0    0.820848  0.279692 -0.933809
# 1   -0.237337  0.123457 -0.147219
# 2   -1.004144 -0.363469 -2.368783
# 3   -0.303728 -0.025726 -1.275006
# 4   -0.750953 -1.433361  1.147996
# ..        ...       ...       ...
# 495 -0.848163 -0.807881 -0.123273
# 496  0.055388  0.021084  0.559810
# 497 -0.753129 -1.264581 -1.127424
# 498 -0.231799 -0.276941 -2.064353
# 499 -0.011838 -0.465866  0.319968
#
# [500 rows x 3 columns]

# %%
df.iloc[0,[1,2,3]]
# Out:
# 1    0.820848
# 2    0.279692
# 3   -0.933809
# Name: 0, dtype: float64

# %%
df.iloc[0:,0].size
# Out:
# 500

# %%
import math
summation = sum(a-b)
print(summation)

a = df.iloc[0, 1:3]

b = df.iloc[2, 1:3]

summation2 = 0
for i in range(b.size):
    k = i+1
    summation2 += ((a.at[k] - b.at[k]) **2)
    

print("summation 2: " + str(math.sqrt(summation2)))
# Out:
# 2.4681526500000004
# summation 2: 1.9350066257674545

# %%
a
# Out:
# 1     0.820848
# 2     0.279692
# 3    -0.933809
# 4     0.531446
# 5    -0.289947
# 6     0.081788
# 7     0.718942
# 8    -0.250738
# 9    -2.224598
# 10    1.393593
# Name: 0, dtype: float64

# %%
b
# Out:
# 1    -1.004144
# 2    -0.363469
# 3    -2.368783
# 4     0.188795
# 5     0.649362
# 6    -0.663043
# 7    -1.565937
# 8     1.278773
# 9    -1.497079
# 10    1.279087
# Name: 2, dtype: float64

# %%
print(b.at[1])
# Out:
# -1.0041435

# %%
df
# Out:
#       0         1         2         3         4         5         6   \
# 0    2.0  0.820848  0.279692 -0.933809  0.531446 -0.289947  0.081788
# 1    2.0 -0.237337  0.123457 -0.147219 -0.169008 -1.906988  0.412150
# 2    2.0 -1.004144 -0.363469 -2.368783  0.188795  0.649362 -0.663043
# 3    2.0 -0.303728 -0.025726 -1.275006 -0.609765  0.306372  0.196949
# 4    2.0 -0.750953 -1.433361  1.147996  1.286011  1.305121  0.664181
# ..   ...       ...       ...       ...       ...       ...       ...
# 495  1.0 -0.848163 -0.807881 -0.123273 -0.744263  0.467340 -1.309142
# 496  2.0  0.055388  0.021084  0.559810 -0.503055 -0.968667  1.684491
# 497  2.0 -0.753129 -1.264581 -1.127424 -0.554393 -0.609218 -0.047186
# 498  2.0 -0.231799 -0.276941 -2.064353 -2.093766 -0.616740 -0.390248
# 499  2.0 -0.011838 -0.465866  0.319968 -1.095462 -1.666040 -0.517896
#
#            7         8         9         10
# 0    0.718942 -0.250738 -2.224598  1.393593
# 1   -0.476520  0.049739 -0.578898  1.474495
# ...

# %%
df2 = df.iloc[0:20, :]

# %%
df2[1].values[:] = 0

# %%
df2
# Out:
#      0    1         2         3         4         5         6         7   \
# 0   2.0  0.0  0.279692 -0.933809  0.531446 -0.289947  0.081788  0.718942
# 1   2.0  0.0  0.123457 -0.147219 -0.169008 -1.906988  0.412150 -0.476520
# 2   2.0  0.0 -0.363469 -2.368783  0.188795  0.649362 -0.663043 -1.565937
# 3   2.0  0.0 -0.025726 -1.275006 -0.609765  0.306372  0.196949  0.181794
# 4   2.0  0.0 -1.433361  1.147996  1.286011  1.305121  0.664181 -0.815684
# 5   2.0  0.0 -0.851389  0.134183  0.231321 -0.008353  0.084643 -2.665728
# 6   2.0  0.0  0.716731  1.071499  1.630986  1.108574 -0.153973 -0.006238
# 7   2.0  0.0 -1.576544  1.119247 -0.494410 -0.427776  1.156893  0.802127
# 8   2.0  0.0  0.737154  0.260962 -0.029296 -1.160268 -1.278653  0.787029
# 9   2.0  0.0 -0.179394  0.762050  0.471370 -0.094831 -1.179684  0.151784
# 10  2.0  0.0 -0.526129  0.149031  0.806586 -0.639835 -1.488777 -0.284936
# 11  2.0  0.0  1.867735  0.039684 -0.409617  0.300956 -0.003657  0.222387
# ...
